# %%
import sqlite3
import pandas as pd

# %%
# %reload_ext sql
# %sql sqlite:///faers-data.sqlite

# %%
# %%sql
# SELECT * FROM DRUG LIMIT 10
# Out:
#  * sqlite:///faers-data.sqlite
# Done.
# [(None, 100100247, 10010024, 1, 'PS', 'ADALIMUMAB', 'ADALIMUMAB', 1, 'Subcutaneous', None, None, None, 'Y', None, 'Not Available', None, '125057', '40', 'MG', None, 'QOW'),
#  (None, 100100247, 10010024, 2, 'SS', 'ADALIMUMAB', 'ADALIMUMAB', 1, None, None, None, None, 'Y', None, None, None, '125057', None, None, None, None),
#  (None, 100100247, 10010024, 3, 'SS', 'CYCLOSPORINE', 'CYCLOSPORINE', 1, 'Unknown', None, None, None, 'D', None, 'Not Available', None, '065003', None, None, None, None),
#  (None, 100100247, 10010024, 4, 'SS', 'REMICADE', 'INFLIXIMAB', 1, 'Intravenous (not otherwise specified)', '6 infusions at 8 weeks interval', None, None, 'Y', None, 'Not Available', None, None, None, None, None, None),
#  (None, 100100247, 10010024, 5, 'SS', 'ETANERCEPT', 'ETANERCEPT', 1, 'Subcutaneous', None, None, None, 'Y', None, 'Not Available', None, None, '100', 'MG', None, '/WK'),
# ...

# %%
# load the drug table as a pandas dataframe
df = %sql SELECT * FROM DRUG
df = df.DataFrame()
df.head()
# Out:
#  * sqlite:///faers-data.sqlite
# Done.
#     ISR  PRIMARYID    CASEID  DRUG_SEQ ROLE_COD      DRUGNAME       PROD_AI  \
# 0  None  100100247  10010024         1       PS    ADALIMUMAB    ADALIMUMAB
# 1  None  100100247  10010024         2       SS    ADALIMUMAB    ADALIMUMAB
# 2  None  100100247  10010024         3       SS  CYCLOSPORINE  CYCLOSPORINE
# 3  None  100100247  10010024         4       SS      REMICADE    INFLIXIMAB
# 4  None  100100247  10010024         5       SS    ETANERCEPT    ETANERCEPT
#
#    VAL_VBM                                  ROUTE  \
# 0        1                           Subcutaneous
# 1        1                                   None
# 2        1                                Unknown
# 3        1  Intravenous (not otherwise specified)
# 4        1                           Subcutaneous
#
#                           DOSE_VBM  ... CUM_DOSE_UNIT DECHAL RECHAL  \
# 0                             None  ...          None      Y   None
# ...

# %%
df.shape
# Out:
# (2030938, 21)
